# %%
import pandas as pd
import numpy as np

# %%
#pd.Series?

my_pets = ['Lion', 'Cat', 'Birds', 'Fish']
my_pets
# Out:
# ['Lion', 'Cat', 'Birds', 'Fish']

# %%
pd.Series(my_pets)
# Out:
# 0     Lion
# 1      Cat
# 2    Birds
# 3     Fish
# dtype: object

# %%
df = pd.Series(['Maths','Chem','Phy','Geo','Ent'], index='Day1 Day2 Day3 Day4 Day4'.split(' '))
df
# Out:
# Day1    Maths
# Day2     Chem
# Day3      Phy
# Day4      Geo
# Day4      Ent
# dtype: object

# %%
my_dataframe = pd.DataFrame(np.random.randn(10,5), index='row1 row2 row3 row4 row5 row6 row7 row8 row9 row10'.split(), columns='column1 column2 column3 column4 column5'.split())
my_dataframe
# Out:
#         column1   column2   column3   column4   column5
# row1  -0.861905 -0.489709 -1.186294  0.846759  1.346563
# row2   0.942163  1.108899  0.150486  0.896780  1.439323
# row3  -0.530431 -0.425580  1.338045  0.791317 -0.186265
# row4   1.351037  0.899351  1.000312  0.752778 -0.000864
# row5  -1.299608  0.208653 -0.804337 -0.244015  0.794414
# row6  -0.660780  0.148236  0.742954  0.780482  0.171164
# row7   1.609042 -0.356589  0.013106 -0.007852 -1.053153
# row8   0.498406  0.398786 -1.735259 -1.555076  1.451060
# row9   1.766689 -0.734322 -0.927992 -0.514171  0.629508
# row10 -0.818694 -1.900291  0.031179 -1.605657  0.155846

# %% [markdown]
# # **Let's Add New Column With DataFrame**

# %%
my_dataframe['column6'] = my_dataframe['column1'] * 2

# %%
my_dataframe
# Out:
#         column1   column2   column3   column4   column5   column6
# row1  -0.861905 -0.489709 -1.186294  0.846759  1.346563 -1.723810
# row2   0.942163  1.108899  0.150486  0.896780  1.439323  1.884327
# row3  -0.530431 -0.425580  1.338045  0.791317 -0.186265 -1.060862
# row4   1.351037  0.899351  1.000312  0.752778 -0.000864  2.702073
# row5  -1.299608  0.208653 -0.804337 -0.244015  0.794414 -2.599216
# row6  -0.660780  0.148236  0.742954  0.780482  0.171164 -1.321561
# row7   1.609042 -0.356589  0.013106 -0.007852 -1.053153  3.218083
# row8   0.498406  0.398786 -1.735259 -1.555076  1.451060  0.996812
# row9   1.766689 -0.734322 -0.927992 -0.514171  0.629508  3.533379
# row10 -0.818694 -1.900291  0.031179 -1.605657  0.155846 -1.637388

# %% [markdown]
# # **Remove Column From DataFrame**

# %%
my_dataframe.drop('column3', axis=1) #Use axis=1 to refer to column or axis=0 to refer to row
# Out:
#         column1   column2   column4   column5   column6
# row1  -0.861905 -0.489709  0.846759  1.346563 -1.723810
# row2   0.942163  1.108899  0.896780  1.439323  1.884327
# row3  -0.530431 -0.425580  0.791317 -0.186265 -1.060862
# row4   1.351037  0.899351  0.752778 -0.000864  2.702073
# row5  -1.299608  0.208653 -0.244015  0.794414 -2.599216
# row6  -0.660780  0.148236  0.780482  0.171164 -1.321561
# row7   1.609042 -0.356589 -0.007852 -1.053153  3.218083
# row8   0.498406  0.398786 -1.555076  1.451060  0.996812
# row9   1.766689 -0.734322 -0.514171  0.629508  3.533379
# row10 -0.818694 -1.900291 -1.605657  0.155846 -1.637388

# %%
my_dataframe.drop('column1', axis=1, inplace=True)  # Use inplace=True to make the changes affect the orginal dataset

# %%
my_dataframe
# Out:
#         column2   column3   column4   column5   column6
# row1  -0.489709 -1.186294  0.846759  1.346563 -1.723810
# row2   1.108899  0.150486  0.896780  1.439323  1.884327
# row3  -0.425580  1.338045  0.791317 -0.186265 -1.060862
# row4   0.899351  1.000312  0.752778 -0.000864  2.702073
# row5   0.208653 -0.804337 -0.244015  0.794414 -2.599216
# row6   0.148236  0.742954  0.780482  0.171164 -1.321561
# row7  -0.356589  0.013106 -0.007852 -1.053153  3.218083
# row8   0.398786 -1.735259 -1.555076  1.451060  0.996812
# row9  -0.734322 -0.927992 -0.514171  0.629508  3.533379
# row10 -1.900291  0.031179 -1.605657  0.155846 -1.637388

# %% [markdown]
# # **Remove Row From DataFrame**

# %%
my_dataframe.drop('row10', axis=0, inplace=True)

# %%
my_dataframe
# Out:
#        column2   column3   column4   column5   column6
# row1 -0.489709 -1.186294  0.846759  1.346563 -1.723810
# row2  1.108899  0.150486  0.896780  1.439323  1.884327
# row3 -0.425580  1.338045  0.791317 -0.186265 -1.060862
# row4  0.899351  1.000312  0.752778 -0.000864  2.702073
# row5  0.208653 -0.804337 -0.244015  0.794414 -2.599216
# row6  0.148236  0.742954  0.780482  0.171164 -1.321561
# row7 -0.356589  0.013106 -0.007852 -1.053153  3.218083
# row8  0.398786 -1.735259 -1.555076  1.451060  0.996812
# row9 -0.734322 -0.927992 -0.514171  0.629508  3.533379

# %%
my_dataframe.loc['row7', 'column4']
# Out:
# -0.007852040105628502

# %%
my_dataframe.iloc[3]
# Out:
# column2    0.899351
# column3    1.000312
# column4    0.752778
# column5   -0.000864
# column6    2.702073
# Name: row4, dtype: float64

# %% [markdown]
# # **Reset the Index**

# %%
my_dataframe.index
# Out:
# Index(['row1', 'row2', 'row3', 'row4', 'row5', 'row6', 'row7', 'row8', 'row9'], dtype='object')

# %%
my_dataframe['spin'] = ['sp1', 'sp2', 'sp3', 'sp4', 'sp5', 'sp6', 'sp7', 'sp8', 'sp9']

# %%
my_dataframe
# Out:
#        column2   column3   column4   column5   column6 spin
# row1 -0.489709 -1.186294  0.846759  1.346563 -1.723810  sp1
# row2  1.108899  0.150486  0.896780  1.439323  1.884327  sp2
# row3 -0.425580  1.338045  0.791317 -0.186265 -1.060862  sp3
# row4  0.899351  1.000312  0.752778 -0.000864  2.702073  sp4
# row5  0.208653 -0.804337 -0.244015  0.794414 -2.599216  sp5
# row6  0.148236  0.742954  0.780482  0.171164 -1.321561  sp6
# row7 -0.356589  0.013106 -0.007852 -1.053153  3.218083  sp7
# row8  0.398786 -1.735259 -1.555076  1.451060  0.996812  sp8
# row9 -0.734322 -0.927992 -0.514171  0.629508  3.533379  sp9

# %%
my_dataframe.set_index('spin', inplace= True)

# %%
my_dataframe
# Out:
#        column2   column3   column4   column5   column6
# spin
# sp1  -0.489709 -1.186294  0.846759  1.346563 -1.723810
# sp2   1.108899  0.150486  0.896780  1.439323  1.884327
# sp3  -0.425580  1.338045  0.791317 -0.186265 -1.060862
# sp4   0.899351  1.000312  0.752778 -0.000864  2.702073
# sp5   0.208653 -0.804337 -0.244015  0.794414 -2.599216
# sp6   0.148236  0.742954  0.780482  0.171164 -1.321561
# sp7  -0.356589  0.013106 -0.007852 -1.053153  3.218083
# sp8   0.398786 -1.735259 -1.555076  1.451060  0.996812
# sp9  -0.734322 -0.927992 -0.514171  0.629508  3.533379

# %% [markdown]
# # **Rename A Column In Pandas Dataframe**

# %%
my_dataframe.rename(columns= {
    'column2':'first',
    'column3':'Second',
    'column4':'third',
    'column5':'fouth',
    'column6':'fith'
}, inplace= True)

# %%
my_dataframe.rename(columns={
    'Seconnd': 'second',
    'four': 'fouth',
    'five': 'fith'
}, inplace= True)

# %%
my_dataframe
# Out:
#          first    Second     third     fouth      fith
# spin
# sp1  -0.489709 -1.186294  0.846759  1.346563 -1.723810
# sp2   1.108899  0.150486  0.896780  1.439323  1.884327
# sp3  -0.425580  1.338045  0.791317 -0.186265 -1.060862
# sp4   0.899351  1.000312  0.752778 -0.000864  2.702073
# sp5   0.208653 -0.804337 -0.244015  0.794414 -2.599216
# sp6   0.148236  0.742954  0.780482  0.171164 -1.321561
# sp7  -0.356589  0.013106 -0.007852 -1.053153  3.218083
# sp8   0.398786 -1.735259 -1.555076  1.451060  0.996812
# sp9  -0.734322 -0.927992 -0.514171  0.629508  3.533379

# %% [markdown]
# # **Conditional Selection With Pandas**

# %%
data = pd.read_csv(r'C:\Users\USER\Documents\Python-For-Data-Science\Datasets\datasets\Automobile.csv')
data.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
data[data['price'] > 40000]
# Out:
#     symboling  normalized_losses           make fuel_type aspiration  \
# 15          0                149            bmw       gas        std
# 70          0                140  mercedes-benz       gas        std
# 71          1                140  mercedes-benz       gas        std
#
#    number_of_doors body_style drive_wheels engine_location  wheel_base  ...  \
# 15             two      sedan          rwd           front       103.5  ...
# 70            four      sedan          rwd           front       120.9  ...
# 71             two    hardtop          rwd           front       112.0  ...
#
#     engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 15          209         mpfi  3.62    3.39               8.0        182
# 70          308         mpfi  3.80    3.35               8.0        184
# 71          304         mpfi  3.80    3.35               8.0        184
#
#     peak_rpm city_mpg  highway_mpg  price
# 15      5400       16           22  41315
# ...

# %% [markdown]
# # **Which car is having the price greater than 20,000**

# %%
data[data['price'] > 20000][['make', 'price']]
# Out:
#               make  price
# 8             audi  23875
# 11             bmw  20970
# 12             bmw  21105
# 13             bmw  24565
# 14             bmw  30760
# 15             bmw  41315
# 16             bmw  36880
# 44          jaguar  32250
# 45          jaguar  35550
# 46          jaguar  36000
# 64   mercedes-benz  25552
# 65   mercedes-benz  28248
# 66   mercedes-benz  28176
# 67   mercedes-benz  31600
# 68   mercedes-benz  34184
# 69   mercedes-benz  35056
# 70   mercedes-benz  40960
# 71   mercedes-benz  45400
# 122        porsche  22018
# 123        porsche  32528
# 124        porsche  34028
# 125        porsche  37028
# 198          volvo  21485
# 199          volvo  22470
# 200          volvo  22625

# %% [markdown]
# # **All the volvo car that are priced less than 50,000**

# %%
data[(data['make'] == 'volvo') & (data['price'] < 50000)] [['make', 'price']]
# Out:
#       make  price
# 190  volvo  12940
# 191  volvo  13415
# 192  volvo  15985
# 193  volvo  16515
# 194  volvo  18420
# 195  volvo  18950
# 196  volvo  16845
# 197  volvo  19045
# 198  volvo  21485
# 199  volvo  22470
# 200  volvo  22625

# %% [markdown]
# # Null Value

# %%
df = pd.DataFrame({'value1':[100,np.nan,234,np.nan],
                   'value2':[300,121,np.nan,np.nan],
                   'value3':['XUI','VYU','NMA','IUY']})
df.head()
# Out:
#    value1  value2 value3
# 0   100.0   300.0    XUI
# 1     NaN   121.0    VYU
# 2   234.0     NaN    NMA
# 3     NaN     NaN    IUY

# %%
df.isna().sum()  # counting the total number of NaN in our dataset
# Out:
# value1    2
# value2    2
# value3    0
# dtype: int64

# %% [markdown]
# # Sort Values In Pandas*

# %%
df
# Out:
#    value1  value2 value3
# 0   100.0   300.0    XUI
# 1     NaN   121.0    VYU
# 2   234.0     NaN    NMA
# 3     NaN     NaN    IUY

# %%
df.sort_values(by='value3', ascending=True)
# Out:
#    value1  value2 value3
# 3     NaN     NaN    IUY
# 2   234.0     NaN    NMA
# 1     NaN   121.0    VYU
# 0   100.0   300.0    XUI

# %%
data
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
data.groupby('fuel_type').count()
# Out:
#            symboling  normalized_losses  make  aspiration  number_of_doors  \
# fuel_type
# diesel            20                 20    20          20               20
# gas              181                181   181         181              181
#
#            body_style  drive_wheels  engine_location  wheel_base  length  ...  \
# fuel_type                                                                 ...
# diesel             20            20               20          20      20  ...
# gas               181           181              181         181     181  ...
#
#            engine_size  fuel_system  bore  stroke  compression_ratio  \
# fuel_type
# diesel              20           20    20      20                 20
# gas                181          181   181     181                181
#
#            horsepower  peak_rpm  city_mpg  highway_mpg  price
# fuel_type
# diesel             20        20        20           20     20
# ...

# %% [markdown]
# # Count() & Value_Count()

# %%
data['make'].count()
# Out:
# 201

# %%
data['make'].value_counts()
# Out:
# make
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# plymouth          7
# audi              6
# saab              6
# porsche           4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# isuzu             2
# renault           2
# mercury           1
# Name: count, dtype: int64

# %% [markdown]
# # Concatenate Function

# %%
mm = {'one':[2,3,1,4,5],
     'two':[5,4,3,2,1],
     'letter':['a','a','b','b','c']}

# %%
mm
# Out:
# {'one': [2, 3, 1, 4, 5],
#  'two': [5, 4, 3, 2, 1],
#  'letter': ['a', 'a', 'b', 'b', 'c']}

# %%
mm1 = pd.DataFrame(mm)

# %%
mm1
# Out:
#    one  two letter
# 0    2    5      a
# 1    3    4      a
# 2    1    3      b
# 3    4    2      b
# 4    5    1      c

# %%
df
# Out:
#    value1  value2 value3
# 0   100.0   300.0    XUI
# 1     NaN   121.0    VYU
# 2   234.0     NaN    NMA
# 3     NaN     NaN    IUY

# %%
new_df = pd.concat([df, mm1])

# %%
new_df
# Out:
#    value1  value2 value3  one  two letter
# 0   100.0   300.0    XUI  NaN  NaN    NaN
# 1     NaN   121.0    VYU  NaN  NaN    NaN
# 2   234.0     NaN    NMA  NaN  NaN    NaN
# 3     NaN     NaN    IUY  NaN  NaN    NaN
# 0     NaN     NaN    NaN  2.0  5.0      a
# 1     NaN     NaN    NaN  3.0  4.0      a
# 2     NaN     NaN    NaN  1.0  3.0      b
# 3     NaN     NaN    NaN  4.0  2.0      b
# 4     NaN     NaN    NaN  5.0  1.0      c

# %% [markdown]
# # Join & Merge(Creating Dataset)

# %%
# Dataframe of number of sales made by an employees
sales = {'Jones': 10000,
         'Chris': 5000,
         'Piyush': 440,
         'Meera': 6700,
         'Rahul': 300
        }
# Dataframe of all employees and the region they work in
region = {'Jones': 'West',
          'Chris': np.nan,
          'Piyush': 'West',
          'Meera': np.nan,
          'Anthony': 'East',
          'Ellen': 'South',
          'Josh': 'West',
          'Simran': 'East',
          'Oscar': 'North',
         }

# %%
sales_df = pd.DataFrame.from_dict(sales, orient= 'index', columns= ['sales'])
sales_df
# Out:
#         sales
# Jones   10000
# Chris    5000
# Piyush    440
# Meera    6700
# Rahul     300

# %%
region_df = pd.DataFrame.from_dict(region, orient= 'index', columns= ['region'])
region_df
# Out:
#         region
# Jones     West
# Chris      NaN
# Piyush    West
# Meera      NaN
# Anthony   East
# Ellen    South
# Josh      West
# Simran    East
# Oscar    North

# %%
joined_df = region_df.join(sales_df, how='left')
joined_df
# Out:
#         region    sales
# Jones     West  10000.0
# Chris      NaN   5000.0
# Piyush    West    440.0
# Meera      NaN   6700.0
# Anthony   East      NaN
# Ellen    South      NaN
# Josh      West      NaN
# Simran    East      NaN
# Oscar    North      NaN

# %%
joined_df = region_df.join(sales_df, how='right')
joined_df
# Out:
#        region  sales
# Jones    West  10000
# Chris     NaN   5000
# Piyush   West    440
# Meera     NaN   6700
# Rahul     NaN    300

# %%
joined_df = region_df.join(sales_df, how='inner')
joined_df
# Out:
#        region  sales
# Jones    West  10000
# Chris     NaN   5000
# Piyush   West    440
# Meera     NaN   6700

# %%
joined_df = region_df.join(sales_df, how='outer')
joined_df
# Out:
#         region    sales
# Anthony   East      NaN
# Chris      NaN   5000.0
# Ellen    South      NaN
# Jones     West  10000.0
# Josh      West      NaN
# Meera      NaN   6700.0
# Oscar    North      NaN
# Piyush    West    440.0
# Rahul      NaN    300.0
# Simran    East      NaN

# %%
#give title to the index column
region_df.index.name='names'
sales_df.index.name='names'

# %%
pd.merge(region_df, sales_df, on='names', how='left')
# Out:
#         region    sales
# names
# Jones     West  10000.0
# Chris      NaN   5000.0
# Piyush    West    440.0
# Meera      NaN   6700.0
# Anthony   East      NaN
# Ellen    South      NaN
# Josh      West      NaN
# Simran    East      NaN
# Oscar    North      NaN
